# %%
# libraries
import pandas as pd

# %%
# load data
curative_pts = pd.read_stata("5year analysis 20200310.dta")
curative_pts
# Out:
#         id  completed4cycles_chemo  no_chemo_cycles  generated_id      omang  \
# 0    AK044                     1.0              4.0     79.400002  621825205
# 1    BB142                     0.0              3.0     60.000000  502029215
# 2    BC146                     0.0              1.0     79.400002  700323006
# 3    BK195                     1.0              4.0    175.000000  860220201
# 4    BL003                     1.0              5.0      4.000000  647724822
# ..     ...                     ...              ...           ...        ...
# 994                            NaN              NaN           NaN
# 995                            NaN              NaN           NaN
# 996                            NaN              NaN           NaN
# 997                            NaN              NaN           NaN
# 998                            NaN              NaN           NaN
#
#      _2_have_you_been_screened_for_c  performance_status  diabetes  \
# ...

# %%
# index 143 patients
curative_pts = curative_pts.iloc[:143, :]
curative_pts#[["vitalstatus", "updatedvitalstatus"]]
# Out:
#         id  completed4cycles_chemo  no_chemo_cycles  generated_id      omang  \
# 0    AK044                     1.0              4.0     79.400002  621825205
# 1    BB142                     0.0              3.0     60.000000  502029215
# 2    BC146                     0.0              1.0     79.400002  700323006
# 3    BK195                     1.0              4.0    175.000000  860220201
# 4    BL003                     1.0              5.0      4.000000  647724822
# ..     ...                     ...              ...           ...        ...
# 138  TD168                     1.0              5.0    152.000000  348023406
# 139  TW198                     1.0              5.0    179.000000  406226515
# 140  VG182                     0.0              1.0    166.000000  204125206
# 141  XX094                     1.0              5.0     83.000000  484429809
# 142  DJ013                     1.0              5.0     14.000000  874522300
#
# ...

# %%
# grab columns used in Surbhi's analysis
curative_pts["dead5year"] = curative_pts["dead5year"].fillna(1)
curative_pts = curative_pts[["id", "xhiv3", "age", "xstage2", "no_chemo_cycles45",
              "hb10", "eqd2", "time_alive", "dead5year"]]

curative_pts.to_csv("curative.csv", index=False)
# Out:
# <ipython-input-4-8f893d16aa55>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   curative_pts["dead5year"] = curative_pts["dead5year"].fillna(1)
